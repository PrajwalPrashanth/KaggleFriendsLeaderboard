# %%
import pandas as pd

# %%
a = 0

# %%
# %%timeit
a = pd.read_csv('a.csv')
print(a)
# Out:
#          Unnamed: 0  Santander Customer Transaction Prediction  \
# 0  prajwalprashanth                                     5908.0
# 1          crazydiv                                     1795.0
# 2            init27                                        NaN
# 3         sidujjain                                        NaN
# 4          aakashns                                        NaN
# 5       nazimgirach                                        NaN
#
#    PetFinder.my Adoption Prediction  LANL Earthquake Prediction
# 0                               NaN                         NaN
# 1                             307.0                         NaN
# 2                              22.0                       448.0
# 3                             343.0                         NaN
# 4                             343.0                      1276.0
# 5                             211.0                         NaN
#          Unnamed: 0  Santander Customer Transaction Prediction  \
# ...

# %%
a.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-4d0f5672653e> in <module>
# ----> 1 a.head()
#
# AttributeError: 'int' object has no attribute 'head'
